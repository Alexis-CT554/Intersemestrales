# %% [markdown]
# # Prepocesamiento de Datos con Python
# ## FES Aragón
# ### ICO --- Sesion 03
# #### Alexis Cano Tapia

# %%
import pandas as pd

# %%
! pip install "pymongo[srv]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymongo[srv] in c:\programdata\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from pymongo[srv]) (2.3.0)

# %%
import pymongo

# %% [markdown]
# ## Conexion con Mongo

# %%
usuario = 'fesalu'
passwd = 'nosqlfes123'
cluster = 'cluster0-shard-00-00.8pyt4.mongodb.net'
n1 = 'cluster0-shard-00-01.8pyt4.mongodb.net'
n2 = 'cluster0-shard-00-02.8pyt4.mongodb.net'
puerto = '27017'
mongo_str = f"mongodb://{usuario}:{passwd}@{cluster}:{puerto},{n1}:{puerto},{n2}:{puerto}/?ssl=true&replicaSet=atlas-nok9e6-shard-0&authSource=admin&retryWrites=true&w=majority"
print(mongo_str)
mongoClient = pymongo.MongoClient(mongo_str)
mongoClient
# Out:
# mongodb://fesalu:nosqlfes123@cluster0-shard-00-00.8pyt4.mongodb.net:27017,cluster0-shard-00-01.8pyt4.mongodb.net:27017,cluster0-shard-00-02.8pyt4.mongodb.net:27017/?ssl=true&replicaSet=atlas-nok9e6-shard-0&authSource=admin&retryWrites=true&w=majority
# MongoClient(host=['cluster0-shard-00-01.8pyt4.mongodb.net:27017', 'cluster0-shard-00-02.8pyt4.mongodb.net:27017', 'cluster0-shard-00-00.8pyt4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-nok9e6-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True)

# %%
#Ver todas las bases de datos disponilbes
mongoClient.list_database_names()
# Out:
# ['OmarMendozaGonzalez',
#  'agenda',
#  'colegio',
#  'fundamentosmongo',
#  'itsa',
#  'pdcd',
#  'taller',
#  'tbd',
#  'tebd',
#  'admin',
#  'local']

# %%
db = mongoClient.colegio
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.8pyt4.mongodb.net:27017', 'cluster0-shard-00-02.8pyt4.mongodb.net:27017', 'cluster0-shard-00-00.8pyt4.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-nok9e6-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True), 'colegio')

# %%
f = db.alumnos.find({'curp': { '$exists': 0 }})
f

# %%
lista_f = list(f)
lista_f
# Out:
# [{'_id': ObjectId('5f873e4a7591b0b48f65faf9'),
#   'clave_alu': 11030177,
#   'ap_paterno': 'FERRUSCA',
#   'ap_materno': 'ANDRADE',
#   'nombre': 'OCTAVIO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'tavoferrus_11@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65faf6'),
#   'clave_alu': 11030172,
#   'ap_paterno': 'BORBOLLA',
#   'ap_materno': 'RAMOS',
#   'nombre': 'ARGELIA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'kargi_gogos@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fafc'),
#   'clave_alu': 11030199,
#   'ap_paterno': 'ROSALES',
#   'ap_materno': 'APREZA',
#   'nombre': 'NESTOR MARTIN',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'nestoriwh@hotmai.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb04'),
#   'clave_alu': 11030217,
#   'ap_paterno': 'FERRUSCA',
#   'ap_materno': 'ANDRADE',
#   'nombre': 'CESAR',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'cesar_tum-b@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fafb'),
#   'clave_alu': 11030173,
#   'ap_paterno': 'CASTRO',
#   'ap_materno': 'MANCERA',
#   'nombre': 'KARLA MARIANA',
#   'sexo': 'F',
#   'ciudad': 'SANTIAGO DE QUERETARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb0b'),
#   'clave_alu': 11030242,
#   'ap_paterno': 'ALCOCER',
#   'ap_materno': 'ESCOBAR',
#   'nombre': 'AGUSTIN',
#   'sexo': 'M'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb06'),
#   'clave_alu': 11030232,
#   'ap_paterno': 'PEREZ',
#   'ap_materno': 'DEL CASTILLO VELASCO',
#   'nombre': 'ESTEBAN',
#   'email': 'estebanlunete@yahoo.com.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb13'),
#   'clave_alu': 11030273,
#   'ap_paterno': 'URIBE',
#   'ap_materno': 'GARCIA',
#   'nombre': 'MARIA GUADALUPE',
#   'ciudad': 'QUERETARO',
#   'email': 'misato227@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb08'),
#   'clave_alu': 11030235,
#   'ap_paterno': 'SAAVEDRA',
#   'ap_materno': 'MARTINEZ',
#   'nombre': 'GABRIEL ANDRES',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'gasaa_10@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb17'),
#   'clave_alu': 11030292,
#   'ap_paterno': 'PEREA',
#   'ap_materno': 'PACHECO',
#   'nombre': 'FERNANDO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb0e'),
#   'clave_alu': 11030213,
#   'ap_paterno': 'COSS',
#   'ap_materno': 'AGUADO',
#   'nombre': 'RAUL ANDRES',
#   'ciudad': 'QUERETARO',
#   'email': 'andrescoss285@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb11'),
#   'clave_alu': 11030268,
#   'ap_paterno': 'MONTIEL',
#   'ap_materno': 'PEREZ',
#   'nombre': 'CARLOS GABRIEL',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'gabos_1803@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fafe'),
#   'clave_alu': 11030204,
#   'ap_paterno': 'VAZQUEZ',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'ROBERTO',
#   'sexo': 'M',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'rob_vaz03@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb1d'),
#   'clave_alu': 11040003,
#   'ap_paterno': 'BARRON',
#   'ap_materno': 'LOEZA',
#   'nombre': 'GABRIELA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'gabybalo89@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb21'),
#   'clave_alu': 11040021,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'MORENO',
#   'nombre': 'MARIA JOSE',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'mahemo_10@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb28'),
#   'clave_alu': 11040046,
#   'ap_paterno': 'AGUIRRE',
#   'ap_materno': 'MARGAIN',
#   'nombre': 'LAURA ALEJANDRA'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb2e'),
#   'clave_alu': 11040035,
#   'ap_paterno': 'PEREZ',
#   'ap_materno': 'RETANA',
#   'nombre': 'DANIEL',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'oraciones_9@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb30'),
#   'clave_alu': 11040043,
#   'ap_paterno': 'VAZQUEZ',
#   'ap_materno': 'ARTEAGA',
#   'nombre': 'THALIA IVETTE',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb33'),
#   'clave_alu': 11040069,
#   'ap_paterno': 'MARUSICH',
#   'ap_materno': 'CASTELLANOS',
#   'nombre': 'ANDRES',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'marucholey@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb32'),
#   'clave_alu': 11040044,
#   'ap_paterno': 'VEGA',
#   'ap_materno': 'VEGA',
#   'nombre': 'ELIZABETH',
#   'ciudad': 'QUERETARO',
#   'email': 'liznena1@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb38'),
#   'clave_alu': 11040074,
#   'ap_paterno': 'OTERO',
#   'ap_materno': 'GARABATOS',
#   'nombre': 'SANTIAGO',
#   'sexo': 'M',
#   'email': 'mirameahuevo@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb3a'),
#   'clave_alu': 11040092,
#   'ap_paterno': 'ARANDA',
#   'ap_materno': 'CALZADA',
#   'nombre': 'MAYELA AMAYRANI'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb3f'),
#   'clave_alu': 11040094,
#   'ap_paterno': 'AYALA',
#   'ap_materno': 'ALCANTARA',
#   'nombre': 'ELVIRA DE JESUS',
#   'sexo': 'F',
#   'ciudad': 'QUER',
#   'email': 'badgirl_2501@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb1f'),
#   'clave_alu': 11040010,
#   'ap_paterno': 'DEL CORRAL',
#   'ap_materno': 'GUERRERO',
#   'nombre': 'ABRAHAM',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb48'),
#   'clave_alu': 11040141,
#   'ap_paterno': 'BRAVO',
#   'ap_materno': 'CORONILLA',
#   'nombre': 'JOSE ANTONIO',
#   'sexo': 'M',
#   'ciudad': 'SANTIAGO DE QUER',
#   'email': 'a_coronilla@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb44'),
#   'clave_alu': 11040128,
#   'ap_paterno': 'ROMAN',
#   'ap_materno': 'AGUILAR',
#   'nombre': 'ZIMRI',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'zimrirw@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb3c'),
#   'clave_alu': 11040078,
#   'ap_paterno': 'RODRIGUEZ',
#   'ap_materno': 'IBARRA',
#   'nombre': 'CHRISTIAN ARTURO',
#   'ciudad': 'QUERETARO',
#   'email': 'oco_1589@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb3d'),
#   'clave_alu': 11040104,
#   'ap_paterno': 'GARCIA',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'DAVID SALOMON',
#   'sexo': 'M'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb4a'),
#   'clave_alu': 11040144,
#   'ap_paterno': 'CASILLAS',
#   'ap_materno': 'PINEDA',
#   'nombre': 'NORMA SELENE',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'selenotalobuenaonda@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb52'),
#   'clave_alu': 11040148,
#   'ap_paterno': 'DOMINGUEZ',
#   'ap_materno': 'GARCIA',
#   'nombre': 'PAULO CESAR',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb39'),
#   'clave_alu': 11040090,
#   'ap_paterno': 'ZORRILLA',
#   'ap_materno': 'TREJO',
#   'nombre': 'LERNA ISSARHELLY',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'lerna_320@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb41'),
#   'clave_alu': 11040113,
#   'ap_paterno': 'NOGUES',
#   'ap_materno': 'BARAJAS',
#   'nombre': 'MARIA FERNANDA',
#   'sexo': 'F',
#   'ciudad': 'MEXICO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb43'),
#   'clave_alu': 11040116,
#   'ap_paterno': 'PARRA',
#   'ap_materno': 'MARTINEZ',
#   'nombre': 'ERICK IVAN',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'coery_parra@homail.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb40'),
#   'clave_alu': 11040109,
#   'ap_paterno': 'LOPEZ',
#   'ap_materno': 'CUEVAS',
#   'nombre': 'OLIVIA DEL CARMEN',
#   'ciudad': 'QUERETARO',
#   'email': 'oli_car@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb54'),
#   'clave_alu': 11040157,
#   'ap_paterno': 'LOARCA',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'ALEJANDRA NOEMI',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO MEXICO',
#   'email': 'ale_loarca@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb5c'),
#   'clave_alu': 11040167,
#   'ap_paterno': 'REYNOSO',
#   'ap_materno': 'SANCHEZ',
#   'nombre': 'LUIS RENE',
#   'ciudad': 'SANTIAGO DE QRO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb55'),
#   'clave_alu': 11040158,
#   'ap_paterno': 'LOPEZ',
#   'ap_materno': 'BARBA',
#   'nombre': 'ANAKAREM',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'pingu_ina03@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb50'),
#   'clave_alu': 11040154,
#   'ap_paterno': 'HURTADO',
#   'ap_materno': 'MENDEZ',
#   'nombre': 'JIMENA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'prinsess_1506@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb42'),
#   'clave_alu': 11040122,
#   'ap_paterno': 'RAMIREZ',
#   'ap_materno': 'LEGORRETA',
#   'nombre': 'ALEJANDRA',
#   'ciudad': 'QUERETARO',
#   'email': 'amaya2907@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb4b'),
#   'clave_alu': 11040145,
#   'ap_paterno': 'CASTRO',
#   'ap_materno': 'FLORES',
#   'nombre': 'DANIEL EDUARDO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'dani_hots@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb53'),
#   'clave_alu': 11040156,
#   'ap_paterno': 'LEON',
#   'ap_materno': 'ZARATE',
#   'nombre': 'NICOLAS',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb68'),
#   'clave_alu': 11040186,
#   'ap_paterno': 'BAUTISTA',
#   'ap_materno': 'SILVA',
#   'nombre': 'LUIS MOISES',
#   'ciudad': 'QUERETARO',
#   'email': 'luis.bautista@municipiodequeretaro.gob.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb67'),
#   'clave_alu': 11040187,
#   'ap_paterno': 'CARRASCO',
#   'ap_materno': 'DORANTES',
#   'nombre': 'ANA DEL CARMEN',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'ani_ta_car@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb64'),
#   'clave_alu': 11040181,
#   'ap_paterno': 'AGUILAR',
#   'ap_materno': 'TORRES',
#   'nombre': 'HECTOR MAURICIO',
#   'sexo': 'M',
#   'email': 'maria.torres@autoliv.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb75'),
#   'clave_alu': 11040202,
#   'ap_paterno': 'MARTIN',
#   'ap_materno': 'RODRIGUEZ',
#   'nombre': 'JOSE MANUEL',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'martinsoyelre@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb7b'),
#   'clave_alu': 11040212,
#   'ap_paterno': 'RIVERA',
#   'ap_materno': 'RAMIREZ',
#   'nombre': 'ALEJANDRA',
#   'sexo': 'F',
#   'ciudad': 'QUER',
#   'email': 'aleja_rira@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb6c'),
#   'clave_alu': 11040191,
#   'ap_paterno': 'DORANTES',
#   'ap_materno': 'ASPEITIA',
#   'nombre': 'GUADALUPE',
#   'ciudad': 'QUERETARO',
#   'email': 'dorantes.oscar@mx.sika.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb83'),
#   'clave_alu': 11040225,
#   'ap_paterno': 'ALVARADO',
#   'ap_materno': 'SALAZAR',
#   'nombre': 'MANUEL',
#   'sexo': 'M',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'the_human_disco_ball@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb87'),
#   'clave_alu': 11040234,
#   'ap_paterno': 'ESCUDERO',
#   'ap_materno': 'OSORNO',
#   'nombre': 'KARLA PAULINA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'pausitamosha_escudero@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb7c'),
#   'clave_alu': 11040211,
#   'ap_paterno': 'RIVERA',
#   'ap_materno': 'ESPINOSA',
#   'nombre': 'MARIO ALBERTO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'mario_6003@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb8b'),
#   'clave_alu': 11040240,
#   'ap_paterno': 'GARCIA',
#   'ap_materno': 'GOMEZ',
#   'nombre': 'MAYRA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'mayra_92g@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb7d'),
#   'clave_alu': 11040213,
#   'ap_paterno': 'RODRIGUEZ',
#   'ap_materno': 'JUAREZ',
#   'nombre': 'MARIO ENRIQUE',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'mariobross922@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb6e'),
#   'clave_alu': 11040193,
#   'ap_paterno': 'GIL',
#   'ap_materno': 'SOLIS',
#   'nombre': 'MIGUEL ANGEL',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'solisgil@prodigy.net.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb85'),
#   'clave_alu': 11040231,
#   'ap_paterno': 'CASTILLO',
#   'ap_materno': 'MARTELL',
#   'nombre': 'JESSICA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'jesicuda_11@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb8e'),
#   'clave_alu': 11040242,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'GUTIERREZ',
#   'nombre': 'EDITH VERONICA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'rimix_3@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb8f'),
#   'clave_alu': 11040244,
#   'ap_paterno': 'LANDAVERDE',
#   'ap_materno': 'MARTINEZ',
#   'nombre': 'JORGE DAVID',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'avelinamr@yahoo.com.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb79'),
#   'clave_alu': 11040206,
#   'ap_paterno': 'NU',
#   'ap_materno': 'GALLEGOS',
#   'nombre': 'ANETTE ITHABICO',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'ana_4228@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb62'),
#   'clave_alu': 11040176,
#   'ap_paterno': 'TOVAR',
#   'ap_materno': 'LOPEZ',
#   'nombre': 'FILIBERTO',
#   'sexo': 'M',
#   'ciudad': 'QUERETATO',
#   'email': 'f_tovar992@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb90'),
#   'clave_alu': 11040237,
#   'ap_paterno': 'ESPINOZA',
#   'ap_materno': 'GARCIA',
#   'nombre': 'EDGAR ISRAEL',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'edgar_51193@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb9f'),
#   'clave_alu': 11040266,
#   'ap_paterno': 'YA',
#   'ap_materno': 'ROBLES',
#   'nombre': 'HONORIO IVAN',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'honoriogym@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fba1'),
#   'clave_alu': 11040267,
#   'ap_paterno': 'AGUILAR',
#   'ap_materno': 'TORRES',
#   'nombre': 'JOSE RODRIGO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'maria.torres@autoliv.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fb78'),
#   'clave_alu': 11040207,
#   'ap_paterno': 'OROZCO',
#   'ap_materno': 'YA',
#   'nombre': 'STEFANIA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'stufda_9@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fba7'),
#   'clave_alu': 11040280,
#   'ap_paterno': 'GUERRA',
#   'ap_materno': 'VAZQUEZ',
#   'nombre': 'NORMANN',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'h2ozarca@yahoo.com.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbb0'),
#   'clave_alu': 11040289,
#   'ap_paterno': 'MARTINEZ',
#   'ap_materno': 'TELLEZ',
#   'nombre': 'MARCELA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'ki92marce594-22@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbaf'),
#   'clave_alu': 11040286,
#   'ap_paterno': 'LOPEZ',
#   'ap_materno': 'MONROY',
#   'nombre': 'DIEGO ANTONIO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'elisabetmonroy@yahoo.com.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbb1'),
#   'clave_alu': 11040290,
#   'ap_paterno': 'MARTINEZ',
#   'ap_materno': 'VILLAGRANA',
#   'nombre': 'ANDREA ALICIA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'andypets_92@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbb2'),
#   'clave_alu': 11040291,
#   'ap_paterno': 'MATA',
#   'ap_materno': 'ARELLANO',
#   'nombre': 'OSCAR ANDRES',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'omatagar@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbbd'),
#   'clave_alu': 11040308,
#   'ap_paterno': 'ZARATE',
#   'ap_materno': 'RODRIGUEZ',
#   'nombre': 'MARIA DEL CARMEN',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'mary_mczr@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbbf'),
#   'clave_alu': 11050016,
#   'ap_paterno': 'GAYOL',
#   'ap_materno': 'DE LA TORRE',
#   'nombre': 'JOSEFINA',
#   'ciudad': 'QUER',
#   'email': 'algebrita@algebrita.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbbc'),
#   'clave_alu': 11040300,
#   'ap_paterno': 'ROCHA',
#   'ap_materno': 'NOVOA',
#   'nombre': 'EDUARDO',
#   'ciudad': 'QUERETARO',
#   'email': 'eduardo_53@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbc4'),
#   'clave_alu': 11050026,
#   'ap_paterno': 'OBESO',
#   'ap_materno': 'MARTINEZ',
#   'nombre': 'TANIA CAROLINA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': '1968ed@prodigy.net.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbaa'),
#   'clave_alu': 11040281,
#   'ap_paterno': 'GUERRERO',
#   'ap_materno': 'ALMANZA',
#   'nombre': 'MIGUEL OMAR',
#   'ciudad': 'QUERETARO',
#   'email': 'moga2415_@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbc9'),
#   'clave_alu': 11050034,
#   'ap_paterno': 'SOBERON',
#   'ap_materno': 'URBIOLA',
#   'nombre': 'JAVIER EUGENIO',
#   'ciudad': 'QUERETARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbc8'),
#   'clave_alu': 11050032,
#   'ap_paterno': 'SANTOYO',
#   'ap_materno': 'MORALES',
#   'nombre': 'MARIA FERNANDA',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbca'),
#   'clave_alu': 11050037,
#   'ap_paterno': 'UGALDE',
#   'ap_materno': 'MEZA',
#   'nombre': 'SAMUEL ULISES',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'samuel_m23@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbb4'),
#   'clave_alu': 11040295,
#   'ap_paterno': 'RAMOS',
#   'ap_materno': 'MARTINEZ',
#   'nombre': 'ALAN EDUARDO',
#   'sexo': 'M'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbcc'),
#   'clave_alu': 11050041,
#   'ap_paterno': 'VILCHES',
#   'ap_materno': 'LINARES',
#   'nombre': 'MARIANA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbd0'),
#   'clave_alu': 11050070,
#   'ap_paterno': 'MARTINEZ',
#   'ap_materno': 'CUELLAR',
#   'nombre': 'SUSANA AZUL',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbcd'),
#   'clave_alu': 11050050,
#   'ap_paterno': 'BARRAGAN',
#   'ap_materno': 'BAEZA',
#   'nombre': 'GLORIA PAULINA',
#   'sexo': 'F',
#   'ciudad': 'QUERETAROQRO',
#   'email': 'paubb90@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbd2'),
#   'clave_alu': 11050075,
#   'ap_paterno': 'PADILLA',
#   'ap_materno': 'BRIZUELA',
#   'nombre': 'LUIS DANIEL',
#   'ciudad': 'QUERETARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbdc'),
#   'clave_alu': 11050096,
#   'ap_paterno': 'CABALLERO DE LOS OLIVOS',
#   'ap_materno': 'VALDESPINO',
#   'nombre': 'KARLA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'kissyfur_86@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbac'),
#   'clave_alu': 11040283,
#   'ap_paterno': 'JIMENEZ',
#   'ap_materno': 'MENDIBUR',
#   'nombre': 'EDGAR ARMANDO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'mendi738@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbd8'),
#   'clave_alu': 11050088,
#   'ap_paterno': 'VICTORICA',
#   'ap_materno': 'BRAVO',
#   'nombre': 'GERARDO',
#   'ciudad': 'QUERETARO',
#   'email': 'ger91_vic09_bra23@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbe3'),
#   'clave_alu': 11050120,
#   'ap_paterno': 'OLVERA',
#   'ap_materno': 'AGUILAR',
#   'nombre': 'JUVENAL',
#   'email': 'juves_3250aguilar@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbe4'),
#   'clave_alu': 11050115,
#   'ap_paterno': 'MARTINEZ',
#   'ap_materno': 'FRANCO',
#   'nombre': 'JUAN CARLOS',
#   'ciudad': 'QUERETARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbd3'),
#   'clave_alu': 11050068,
#   'ap_paterno': 'LUIS',
#   'ap_materno': 'LUIS',
#   'nombre': 'DAVID ALEJANDRO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'crazyhorse_21@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbe1'),
#   'clave_alu': 11050113,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'VITAL',
#   'nombre': 'ADRIANA ANDREA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'andreavital_30@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbec'),
#   'clave_alu': 11050153,
#   'ap_paterno': 'LOO',
#   'ap_materno': 'ESTRADA',
#   'nombre': 'ANDREA',
#   'ciudad': 'QUERETARO',
#   'email': 'andrealooe@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbf1'),
#   'clave_alu': 11050155,
#   'ap_paterno': 'LOPEZ',
#   'ap_materno': 'SALDA',
#   'nombre': 'LESLIE EDITH',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbde'),
#   'clave_alu': 11050102,
#   'ap_paterno': 'CHAVEZ',
#   'ap_materno': 'MU',
#   'nombre': 'ANDREA',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbd4'),
#   'clave_alu': 11050076,
#   'ap_paterno': 'PRADO',
#   'ap_materno': 'PE',
#   'nombre': 'KARLA PATRICIA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'azulviajes@prodigy.net.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbea'),
#   'clave_alu': 11050141,
#   'ap_paterno': 'CRUZ',
#   'ap_materno': 'ABAD',
#   'nombre': 'ALEJANDRA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'nopalita_10@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbee'),
#   'clave_alu': 11050152,
#   'ap_paterno': 'JUAREZ',
#   'ap_materno': 'URBINA',
#   'nombre': 'EDUARDO ALEJANDRO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'eduard_dunno@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbf3'),
#   'clave_alu': 11050177,
#   'ap_paterno': 'ZARDAIN',
#   'ap_materno': 'CASTELAZO',
#   'nombre': 'GONZALO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'gonzardain@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbf5'),
#   'clave_alu': 11050163,
#   'ap_paterno': 'OLVERA',
#   'ap_materno': 'NAVARRO',
#   'nombre': 'ELIZABETH',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'bengala_25@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbe8'),
#   'clave_alu': 11050137,
#   'ap_paterno': 'BENITEZ',
#   'ap_materno': 'MORALES',
#   'nombre': 'ARTURO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'benitez_007@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbe6'),
#   'clave_alu': 11050133,
#   'ap_paterno': 'ALATORRE',
#   'ap_materno': 'DIAZ',
#   'nombre': 'JOSE ROBERTO',
#   'ciudad': 'QUERETARO',
#   'email': 'roberto_ole@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbf8'),
#   'clave_alu': 11050190,
#   'ap_paterno': 'BRAVO',
#   'ap_materno': 'HUERTA',
#   'nombre': 'ANA KAREN',
#   'ciudad': 'QUERETARO',
#   'email': 'nerakbh@email.com',
#   'materias': ['HISTORIA', 'QUIMICA', 'INGLES', 'MATEMATICAS', 'ETICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc02'),
#   'clave_alu': 11050206,
#   'ap_paterno': 'JIMENEZ',
#   'ap_materno': 'BADAGER',
#   'nombre': 'TANIARHY BERENICE',
#   'email': 'taniarhybadager@email.com',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbfd'),
#   'clave_alu': 11050198,
#   'ap_paterno': 'ESPINO',
#   'ap_materno': 'DE ALBA',
#   'nombre': 'LUIS',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'luis_dealba@email.com',
#   'materias': ['HISTORIA', 'QUIMICA', 'INGLES', 'MATEMATICAS', 'ETICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbf0'),
#   'clave_alu': 11050157,
#   'ap_paterno': 'MALAGON',
#   'ap_materno': 'ZU',
#   'nombre': 'DIEGO EMILIO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'diegols_9@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc0c'),
#   'clave_alu': 11050234,
#   'ap_paterno': 'GARCIA',
#   'ap_materno': 'DE LA TORRE',
#   'nombre': 'GERMAN',
#   'ciudad': 'QUERETARO',
#   'email': 'cristina.delatorre@municipiodequeretaro.gob.mx',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbfc'),
#   'clave_alu': 11050195,
#   'ap_paterno': 'DE LA GARZA',
#   'ap_materno': 'PACHECO',
#   'nombre': 'JOSE LUIS',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fbe9'),
#   'clave_alu': 11050136,
#   'ap_paterno': 'AVILA',
#   'ap_materno': 'AVILES',
#   'nombre': 'JESUS MANUEL',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc16'),
#   'clave_alu': 11050248,
#   'ap_paterno': 'MARTINEZ',
#   'ap_materno': 'CARDENAS',
#   'nombre': 'CAROLINA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'materias': ['HISTORIA', 'QUIMICA', 'INGLES', 'MATEMATICAS', 'ETICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc1f'),
#   'clave_alu': 11050260,
#   'ap_paterno': 'RODRIGUEZ',
#   'ap_materno': 'MELGOZA',
#   'nombre': 'ERICK IVAN',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'erick_nike11@email.com',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc1b'),
#   'clave_alu': 11050256,
#   'ap_paterno': 'OLVERA',
#   'ap_materno': 'GUTIERREZ',
#   'nombre': 'VALERIA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'fernando.olvera@sat.gob.mx',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc18'),
#   'clave_alu': 11050251,
#   'ap_paterno': 'MICHEL',
#   'ap_materno': 'VAZQUEZ MELLADO',
#   'nombre': 'MARIA PIA',
#   'ciudad': 'QUERETARO',
#   'materias': ['HISTORIA', 'QUIMICA', 'INGLES', 'MATEMATICAS', 'ETICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc23'),
#   'clave_alu': 11050269,
#   'ap_paterno': 'ARMENDARIZ',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'JOSE ALEJANDRO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'ileana_rq@email.com',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc2d'),
#   'clave_alu': 11050268,
#   'ap_paterno': 'ALCANTARA',
#   'ap_materno': 'ORTIZ',
#   'nombre': 'ARMANDO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'aao91@email.com',
#   'materias': ['HISTORIA', 'QUIMICA', 'INGLES', 'MATEMATICAS', 'ETICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc2b'),
#   'clave_alu': 11050281,
#   'ap_paterno': 'GARDU',
#   'ap_materno': 'MARTINEZ',
#   'nombre': 'ELIZABETH',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'jcgarduno@mailusebeq.sep.gob.mx',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc25'),
#   'clave_alu': 11050273,
#   'ap_paterno': 'CID',
#   'ap_materno': 'RAMIREZ',
#   'nombre': 'VICTOR ALFONSO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'cid_mora@email.com',
#   'materias': ['HISTORIA', 'QUIMICA', 'INGLES', 'MATEMATICAS', 'ETICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc22'),
#   'clave_alu': 11050264,
#   'ap_paterno': 'SUAREZ',
#   'ap_materno': 'HERNANDEZ',
#   'nombre': 'SERGIO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'checo_301@email.com',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc37'),
#   'clave_alu': 11050301,
#   'ap_paterno': 'RODRIGUEZ',
#   'ap_materno': 'BRAVO',
#   'nombre': 'JOSE MANUEL',
#   'ciudad': 'QUERETARO',
#   'email': 'matere0512@email.com',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc36'),
#   'clave_alu': 11050298,
#   'ap_paterno': 'QUINTANILLA',
#   'ap_materno': 'INFANTE',
#   'nombre': 'LUIS FERNANDO',
#   'sexo': 'M',
#   'email': 'fernando4481@email.com',
#   'materias': ['HISTORIA', 'QUIMICA', 'INGLES', 'MATEMATICAS', 'ETICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc3f'),
#   'clave_alu': 11050320,
#   'ap_paterno': 'GOMEZ',
#   'ap_materno': 'RENTERIA',
#   'nombre': 'LUISA ANDREA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'dr_gomezrehab@yahoo.com.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc4b'),
#   'clave_alu': 11050348,
#   'ap_paterno': 'SUAREZ',
#   'ap_materno': 'DE LA MACORRA',
#   'nombre': 'SANTIAGO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'jsuarez56@newmail.com',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc50'),
#   'clave_alu': 11060004,
#   'ap_paterno': 'AGUILA',
#   'ap_materno': 'SALGADO',
#   'nombre': 'LEOPOLDO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'polo_caritafeliz@email.com',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc5c'),
#   'clave_alu': 11060023,
#   'ap_paterno': 'BUERGO',
#   'ap_materno': 'MARTINEZ',
#   'nombre': 'FERNANDO',
#   'ciudad': 'QUERETARO',
#   'email': 'fer-buer-47@email.com',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc5d'),
#   'clave_alu': 11060026,
#   'ap_paterno': 'CALLEJA',
#   'ap_materno': 'RUIZ',
#   'nombre': 'AIDA MARIA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'achichinkla_amcr@email.com',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc63'),
#   'clave_alu': 11060034,
#   'ap_paterno': 'CERVANTES',
#   'ap_materno': 'CABRERA',
#   'nombre': 'NOA ESTHER',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'noa_cervantes@email.com',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc67'),
#   'clave_alu': 11060038,
#   'ap_paterno': 'COTA',
#   'ap_materno': 'PACHECO',
#   'nombre': 'MARIA RENEE',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc6b'),
#   'clave_alu': 11060047,
#   'ap_paterno': 'DIAZ BARRIGA',
#   'ap_materno': 'GUTIERREZ',
#   'nombre': 'ARTURO AGUSTIN',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'soreimglavin@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc56'),
#   'clave_alu': 11060017,
#   'ap_paterno': 'BARCENAS',
#   'ap_materno': 'ESCOBEDO',
#   'nombre': 'MARTIN ALFONSO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc57'),
#   'clave_alu': 11060018,
#   'ap_paterno': 'BARRAGAN',
#   'ap_materno': 'BAEZA',
#   'nombre': 'ASHLEY MIGUEL',
#   'ciudad': 'QUERETAROQRO',
#   'email': 'gloriabll@email.com',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc5a'),
#   'clave_alu': 11060020,
#   'ap_paterno': 'BENITEZ',
#   'ap_materno': 'MORALES',
#   'nombre': 'GABRIELA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'benitez_007@email.com',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc7e'),
#   'clave_alu': 11060069,
#   'ap_paterno': 'HEREDIA',
#   'ap_materno': 'ORTEGA',
#   'nombre': 'LUIS ANDRES',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'riotgirlfesch@email.com',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc73'),
#   'clave_alu': 11060053,
#   'ap_paterno': 'FERRUSCA',
#   'ap_materno': 'ANDRADE',
#   'nombre': 'ALAN',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'calambres_94@email.com',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc84'),
#   'clave_alu': 11060074,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'PACHECO',
#   'nombre': 'JOSE DANIEL',
#   'sexo': 'M',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc82'),
#   'clave_alu': 11060072,
#   'ap_paterno': 'HERNANDEZ',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'OMAR',
#   'sexo': 'M',
#   'ciudad': 'SANTIAGO DE QUERETARO QRO.',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fc6d'),
#   'clave_alu': 11060045,
#   'ap_paterno': 'DE LA TORRE',
#   'ap_materno': 'NIETO',
#   'nombre': 'RAUL',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'lecuquemonga@email.com',
#   'evaluaciones': [{'materia': 'FIS',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'HIS',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 6.0,
# ...
#   'ap_paterno': 'TEJEDA',
#   'ap_materno': 'ORTEGA',
#   'nombre': 'LUIS RODRIGO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'male2408@email.com',
#   'materias': ['ESPAÑOL', 'MATEMATICAS', 'HISTORIA', 'QUIMICA'],
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'FIS',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'HM',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'QUI',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fce5'),
#   'clave_alu': 11060203,
#   'ap_paterno': 'JUVERA',
#   'ap_materno': 'AVALOS',
#   'nombre': 'EDGAR RODRIGO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'eloriginal0077@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fcec'),
#   'clave_alu': 11060213,
#   'ap_paterno': 'BOLA',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'ESTEFANIA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'esbogo75@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fcf2'),
#   'clave_alu': 11060226,
#   'ap_paterno': 'HERRERA',
#   'ap_materno': 'HUERTA',
#   'nombre': 'CARLOS',
#   'ciudad': 'QUERETARO',
#   'email': 'charsz@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fcf6'),
#   'clave_alu': 11060244,
#   'ap_paterno': 'SANCHEZ ARMAS',
#   'ap_materno': 'GARCIA',
#   'nombre': 'JIMENA',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fced'),
#   'clave_alu': 11060212,
#   'ap_paterno': 'ARELLANO',
#   'ap_materno': 'BERNAL',
#   'nombre': 'JORGE ALBERTO',
#   'sexo': 'M',
#   'ciudad': 'SANTIAGO DE QUERETATARO',
#   'email': 'jaab1289@yahoo.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fcf5'),
#   'clave_alu': 11060240,
#   'ap_paterno': 'PARAMO',
#   'ap_materno': 'FISCAL',
#   'nombre': 'LETICIA',
#   'ciudad': 'ACAMBARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fce8'),
#   'clave_alu': 11060206,
#   'ap_paterno': 'ROBLEDA',
#   'ap_materno': 'CARBAJAL',
#   'nombre': 'VICENTE',
#   'sexo': 'M'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fcf8'),
#   'clave_alu': 11060256,
#   'ap_paterno': 'SANTELICES',
#   'ap_materno': 'AMBRIZ',
#   'nombre': 'ALTAYRA',
#   'ciudad': 'SANTIAGO DE QUERETARO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fcf1'),
#   'clave_alu': 11060220,
#   'ap_paterno': 'DEL RIO',
#   'ap_materno': 'MEDINA',
#   'nombre': 'DANIEL ALONSO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'd_alonso_rm@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd0e'),
#   'clave_alu': 11070075,
#   'ap_paterno': 'VAZQUEZ',
#   'ap_materno': 'MORA',
#   'nombre': 'GERARDO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'gera_plo@email.com',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd0f'),
#   'clave_alu': 11070093,
#   'ap_paterno': 'MONTEMAYOR',
#   'ap_materno': 'REYES',
#   'nombre': 'ADRIAN',
#   'ciudad': 'QUERETARO',
#   'email': 'ymontema@email.com',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd12'),
#   'clave_alu': 11070112,
#   'ap_paterno': 'ALCOCER',
#   'ap_materno': 'RAMOS',
#   'nombre': 'LUIS EMILIO',
#   'sexo': 'M',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd16'),
#   'clave_alu': 11070116,
#   'ap_paterno': 'ARCILA',
#   'ap_materno': 'BARRON',
#   'nombre': 'LUIS GERARDO',
#   'sexo': 'M',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd17'),
#   'clave_alu': 11070113,
#   'ap_paterno': 'ALFARO',
#   'ap_materno': 'CORONEL',
#   'nombre': 'ANDREA',
#   'sexo': 'F',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd18'),
#   'clave_alu': 11070117,
#   'ap_paterno': 'ARROYO',
#   'ap_materno': 'FLORES',
#   'nombre': 'DIANA ELIZABETH',
#   'sexo': 'F',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd19'),
#   'clave_alu': 11070118,
#   'ap_paterno': 'AUDI',
#   'ap_materno': 'LUGO',
#   'nombre': 'JOSE ALBERTO',
#   'sexo': 'M',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd0d'),
#   'clave_alu': 11070084,
#   'ap_paterno': 'GAMEZ',
#   'ap_materno': 'ALVAREZ',
#   'nombre': 'FRANCISCO JAVIER',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'janetha2003@email.comjanadegam@newmail.com',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd1e'),
#   'clave_alu': 11070167,
#   'ap_paterno': 'PI',
#   'ap_materno': 'VEGA',
#   'nombre': 'ROGELIO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'ropi94@email.com',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 10.0,
#     'fecha': datetime.datetime(2020, 11, 5, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 9.0,
#     'fecha': datetime.datetime(2020, 12, 5, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd14'),
#   'clave_alu': 11070114,
#   'ap_paterno': 'ALVAREZ',
#   'ap_materno': 'BACA',
#   'nombre': 'MAURO',
#   'sexo': 'M',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 7.0,
#     'fecha': datetime.datetime(2021, 2, 2, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 5.0,
#     'fecha': datetime.datetime(2021, 3, 31, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd1b'),
#   'clave_alu': 11070119,
#   'ap_paterno': 'BARRON',
#   'ap_materno': 'PEREZ',
#   'nombre': 'KARLA DANIELA',
#   'sexo': 'F',
#   'evaluaciones': [{'materia': 'OPT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)},
#    {'materia': 'ESP',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'ING',
#     'calificacion': 8.0,
#     'fecha': datetime.datetime(2021, 1, 3, 0, 0)},
#    {'materia': 'MAT',
#     'calificacion': 6.0,
#     'fecha': datetime.datetime(2021, 3, 4, 0, 0)}]},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd37'),
#   'clave_alu': 11070367,
#   'ap_paterno': 'CRUZ',
#   'ap_materno': 'PEREZ',
#   'nombre': 'JOSE LIBERIO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO DE ARTEAGA',
#   'email': 'shinta_cruz@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd4a'),
#   'clave_alu': 11080001,
#   'ap_paterno': 'MENDOZA',
#   'ap_materno': 'GONZALEZ',
#   'nombre': 'OMAR'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd4c'),
#   'clave_alu': 11080003,
#   'ap_paterno': 'AMBRIZ',
#   'ap_materno': 'MEDAL',
#   'nombre': 'JESUS EMMANUEL',
#   'sexo': 'M'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd4e'),
#   'clave_alu': 11080006,
#   'ap_paterno': 'BRAVO',
#   'ap_materno': 'CORONILLA',
#   'nombre': 'MARIO FERNANDO',
#   'sexo': 'M'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd4f'),
#   'clave_alu': 11080005,
#   'ap_paterno': 'CAMPOS',
#   'ap_materno': 'ALDAPE',
#   'nombre': 'VALERIA ELOINA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'rotce_campos_9317@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd58'),
#   'clave_alu': 11080018,
#   'ap_paterno': 'CASTILLO',
#   'ap_materno': 'CARDENAS',
#   'nombre': 'VIVIANA'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd5a'),
#   'clave_alu': 11080016,
#   'ap_paterno': 'CANO',
#   'ap_materno': 'SANCHEZ',
#   'nombre': 'OCTAVIO DAVID',
#   'sexo': 'M'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd53'),
#   'clave_alu': 11080011,
#   'ap_paterno': 'BARRERA',
#   'ap_materno': 'CURTIDOR',
#   'nombre': 'HUGO',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'mbt67mx@aol.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd4d'),
#   'clave_alu': 11080004,
#   'ap_paterno': 'BERMUDEZ',
#   'ap_materno': 'TREJO',
#   'nombre': 'ISAAC EDUARDO',
#   'sexo': 'M'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd66'),
#   'clave_alu': 11080030,
#   'ap_paterno': 'GARREL',
#   'ap_materno': '',
#   'nombre': 'ANDRE',
#   'sexo': 'M'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd64'),
#   'clave_alu': 11080028,
#   'ap_paterno': 'GAMEZ',
#   'ap_materno': 'ALVAREZ',
#   'nombre': 'ANA ESTEFANIA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'janetha2003@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd77'),
#   'clave_alu': 11080048,
#   'ap_paterno': 'JUAREZ',
#   'ap_materno': 'GUTIERREZ',
#   'nombre': 'ITZEL GUADALUPE',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd6f'),
#   'clave_alu': 11080039,
#   'ap_paterno': 'GRANADOS',
#   'ap_materno': 'VARGAS',
#   'nombre': 'JOSE FRANCISCO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd7b'),
#   'clave_alu': 11080054,
#   'ap_paterno': 'MACIAS',
#   'ap_materno': 'OLVERA',
#   'nombre': 'ANGELA ADRIANA',
#   'sexo': 'F',
#   'ciudad': 'QUER'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd69'),
#   'clave_alu': 11080032,
#   'ap_paterno': 'GIL',
#   'ap_materno': 'MEDINA',
#   'nombre': 'LIBNI ARELI'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd7a'),
#   'clave_alu': 11080056,
#   'ap_paterno': 'MAYA',
#   'ap_materno': 'OROZCO',
#   'nombre': 'GERARDO ALEJANDRO',
#   'sexo': 'M',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'robb.26@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd74'),
#   'clave_alu': 11080045,
#   'ap_paterno': 'JAIME',
#   'ap_materno': 'VENTURA',
#   'nombre': 'LUIS ANGEL',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO',
#   'email': 'juan.jaime@mabe.com.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd8f'),
#   'clave_alu': 11080073,
#   'ap_paterno': 'RAMOS',
#   'ap_materno': 'FLORES',
#   'nombre': 'JORDAN ALEJANDRO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd8a'),
#   'clave_alu': 11080065,
#   'ap_paterno': 'NIETO',
#   'ap_materno': 'BRICIO',
#   'nombre': 'ANA PAULA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'normaelena75@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd9d'),
#   'clave_alu': 11080086,
#   'ap_paterno': 'SERRATO',
#   'ap_materno': 'SANTANA',
#   'nombre': 'JUAN IVAN'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fda2'),
#   'clave_alu': 11080093,
#   'ap_paterno': 'URIBE',
#   'ap_materno': 'MARTINEZ',
#   'nombre': 'ANA KAREN'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd9b'),
#   'clave_alu': 11080084,
#   'ap_paterno': 'SANCHEZ',
#   'ap_materno': 'ROJAS',
#   'nombre': 'JULIO CESAR',
#   'sexo': 'M',
#   'ciudad': 'QUERETARO QRO.',
#   'email': 'arojas24@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fda7'),
#   'clave_alu': 11080097,
#   'ap_paterno': 'VEGA',
#   'ap_materno': 'CONTRERAS',
#   'nombre': 'BRENDA SUGEY',
#   'sexo': 'F',
#   'ciudad': 'QUER'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdac'),
#   'clave_alu': 11080101,
#   'ap_paterno': 'YA',
#   'ap_materno': 'CAMPOS',
#   'nombre': 'CHRISTIAN ERNESTO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdb1'),
#   'clave_alu': 11080106,
#   'ap_paterno': 'DELGADO',
#   'ap_materno': 'ESPINOSA',
#   'nombre': 'ANDREA',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fda8'),
#   'clave_alu': 11080098,
#   'ap_paterno': 'VELEZ',
#   'ap_materno': 'DAVILA',
#   'nombre': 'CARLOS EDUARDO'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fd9e'),
#   'clave_alu': 11080089,
#   'ap_paterno': 'TEJEDA',
#   'ap_materno': 'ORTEGA',
#   'nombre': 'LORENA',
#   'sexo': 'F',
#   'ciudad': 'SANTIAGO DE QUERETARO',
#   'email': 'elena.ortega@municipiodequeretaro.gob.mx'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fdab'),
#   'clave_alu': 11080102,
#   'ap_paterno': 'YA',
#   'ap_materno': 'ROBLES',
#   'nombre': 'PRISCILA',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fda1'),
#   'clave_alu': 11080092,
#   'ap_paterno': 'UGALDE',
#   'ap_materno': 'SANDERS',
#   'nombre': 'PAULINA CARMEN',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'eduardougalde@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fde9'),
#   'clave_alu': 11080166,
#   'ap_paterno': 'ROSALES',
#   'ap_materno': 'AVILA',
#   'nombre': 'STEPHANIA',
#   'sexo': 'F',
#   'ciudad': 'QUERETARO',
#   'email': 'manueljimav@email.com'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe10'),
#   'clave_alu': 11080209,
#   'ap_paterno': 'MORALES',
#   'ap_materno': 'CARMONA',
#   'nombre': 'KARLA MARIANA',
#   'sexo': 'F'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe16'),
#   'clave_alu': 120800002,
#   'ap_paterno': 'Mendoza',
#   'ap_materno': 'G',
#   'nombre': 'Omar'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe1a'),
#   'clave_alu': 14080001,
#   'ap_paterno': 'MEJIA',
#   'ap_materno': 'JIMENEZ',
#   'nombre': 'LUISA'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe1d'),
#   'clave_alu': 12080001,
#   'ap_paterno': '',
#   'ap_materno': '',
#   'nombre': ''},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe19'),
#   'clave_alu': 14080002,
#   'ap_paterno': 'MEJIA',
#   'ap_materno': 'JIMENEZ',
#   'nombre': 'LUISA'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe1b'),
#   'clave_alu': 14080003,
#   'ap_paterno': 'MEJIA',
#   'ap_materno': 'JIMENEZ',
#   'nombre': 'LUISA'},
#  {'_id': ObjectId('5f873e4a7591b0b48f65fe1c'),
#   'clave_alu': 14080004,
#   'ap_paterno': 'MEJIA',
#   'ap_materno': 'JIMENEZ',
#   'nombre': 'LUISA'}]

# %%
df_mongo = pd.DataFrame(lista_f)
df_mongo
# Out:
#                           _id  clave_alu ap_paterno ap_materno         nombre  \
# 0    5f873e4a7591b0b48f65faf9   11030177   FERRUSCA    ANDRADE        OCTAVIO
# 1    5f873e4a7591b0b48f65faf6   11030172   BORBOLLA      RAMOS        ARGELIA
# 2    5f873e4a7591b0b48f65fafc   11030199    ROSALES     APREZA  NESTOR MARTIN
# 3    5f873e4a7591b0b48f65fb04   11030217   FERRUSCA    ANDRADE          CESAR
# 4    5f873e4a7591b0b48f65fafb   11030173     CASTRO    MANCERA  KARLA MARIANA
# ..                        ...        ...        ...        ...            ...
# 197  5f873e4a7591b0b48f65fe1a   14080001      MEJIA    JIMENEZ          LUISA
# 198  5f873e4a7591b0b48f65fe1d   12080001
# 199  5f873e4a7591b0b48f65fe19   14080002      MEJIA    JIMENEZ          LUISA
# 200  5f873e4a7591b0b48f65fe1b   14080003      MEJIA    JIMENEZ          LUISA
# 201  5f873e4a7591b0b48f65fe1c   14080004      MEJIA    JIMENEZ          LUISA
#
#     sexo                 ciudad                    email materias evaluaciones
# 0      M              QUERETARO  tavoferrus_11@email.com      NaN          NaN
# 1      F              QUERETARO    kargi_gogos@email.com      NaN          NaN
# 2      M              QUERETARO     nestoriwh@hotmai.com      NaN          NaN
# 3      M              QUERETARO    cesar_tum-b@email.com      NaN          NaN
# 4      F  SANTIAGO DE QUERETARO                      NaN      NaN          NaN
# ..   ...                    ...                      ...      ...          ...
# 197  NaN                    NaN                      NaN      NaN          NaN
# 198  NaN                    NaN                      NaN      NaN          NaN
# 199  NaN                    NaN                      NaN      NaN          NaN
# 200  NaN                    NaN                      NaN      NaN          NaN
# 201  NaN                    NaN                      NaN      NaN          NaN
#
# [202 rows x 10 columns]

# %% [markdown]
# ## Conexion Mediante HTML

# %%
url = 'https://es.wikipedia.org/wiki/ISO_3166-2:MX'
df_html = pd.read_html(url)
print(type(df_html))
df_html
# Out:
# <class 'list'>
# [                                               Estado  \
#  0                                      Aguascalientes
#  1                                     Baja California
#  2                                 Baja California Sur
#  3                                            Campeche
#  4                                             Chiapas
#  5                                           Chihuahua
#  6                                    Ciudad de México
#  7                                            Coahuila
#  8                                              Colima
#  9                                             Durango
#  10                                         Guanajuato
#  11                                           Guerrero
#  12                                            Hidalgo
#  13                                            Jalisco
#  14                                             México
#  15                                          Michoacán
#  16                                            Morelos
#  17                                            Nayarit
#  18                                         Nuevo León
#  19                                             Oaxaca
#  20                                             Puebla
#  21                                          Querétaro
#  22                                       Quintana Roo
#  23                                    San Luis Potosí
#  24                                            Sinaloa
#  25                                             Sonora
#  26                                            Tabasco
#  27                                         Tamaulipas
#  28                                           Tlaxcala
#  29                                           Veracruz
#  30                                            Yucatán
#  31                                          Zacatecas
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                               Variable  \
#  0                                                Ags.
#  1                                                B.C.
#  2                                              B.C.S.
#  3                                               Camp.
#  4                                               Chis.
#  5                                               Chih.
#  6                                             C.D.Mx.
#  7                                               Coah.
#  8                                                Col.
#  9                                                Dgo.
#  10                                               Gto.
#  11                                               Gro.
#  12                                               Hgo.
#  13                                               Jal.
#  14                                      Edo. Méx.[D]​
#  15                                              Mich.
#  16                                               Mor.
#  17                                               Nay.
#  18                                               N.L.
#  19                                               Oax.
#  20                                               Pue.
#  21                                               Qro.
#  22                                        Q. Roo.[F]​
#  23                                             S.L.P.
#  24                                               Sin.
#  25                                               Son.
#  26                                               Tab.
#  27                                             Tamps.
#  28                                              Tlax.
#  29                                               Ver.
#  30                                               Yuc.
#  31                                               Zac.
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                             RENAPO[A]​  \
#  0                                                  AS
#  1                                                  BC
#  2                                                  BS
#  3                                                  CC
#  4                                                  CS
#  5                                                  CH
#  6                                                  DF
#  7                                                  CL
#  8                                                  CM
#  9                                                  DG
#  10                                                 GT
#  11                                                 GR
#  12                                                 HG
#  13                                                 JC
#  14                                                 MC
#  15                                                 MN
#  16                                                 MS
#  17                                                 NT
#  18                                                 NL
#  19                                                 OC
#  20                                                 PL
#  21                                                 QO
#  22                                                 QR
#  23                                                 SP
#  24                                                 SL
#  25                                                 SR
#  26                                                 TC
#  27                                                 TS
#  28                                                 TL
#  29                                                 VZ
#  30                                                 YN
#  31                                                 ZS
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                             Dos letras  \
#  0                                                  AG
#  1                                                  BC
#  2                                                  BS
#  3                                                  CM
#  4                                                  CS
#  5                                                  CH
#  6                                              CX[B]​
#  7                                                  CO
#  8                                                  CL
#  9                                                  DG
#  10                                                 GT
#  11                                                 GR
#  12                                                 HG
#  13                                                 JC
#  14                                             EM[E]​
#  15                                                 MI
#  16                                                 MO
#  17                                                NaN
#  18                                                 NL
#  19                                                 OA
#  20                                                 PU
#  21                                                 QT
#  22                                                 QR
#  23                                                 SL
#  24                                                 SI
#  25                                                 SO
#  26                                                 TB
#  27                                                 TM
#  28                                                 TL
#  29                                                 VE
#  30                                                 YU
#  31                                                 ZA
#  32  Notas: ↑ Registro Nacional de Población México...
#
#                                  Completo (ISO 3166-2)
#  0                                              MX-AGU
#  1                                              MX-BCN
#  2                                              MX-BCS
#  3                                              MX-CAM
#  4                                              MX-CHP
#  5                                              MX-CHH
#  6                                          MX-CMX[C]​
#  7                                              MX-COA
#  8                                              MX-COL
#  9                                              MX-DUR
#  10                                             MX-GUA
#  11                                             MX-GRO
#  12                                             MX-HID
#  13                                             MX-JAL
#  14                                             MX-MEX
#  15                                             MX-MIC
#  16                                             MX-MOR
#  17                                             MX-NAY
#  18                                             MX-NLE
#  19                                             MX-OAX
#  20                                             MX-PUE
#  21                                             MX-QUE
#  22                                             MX-ROO
#  23                                             MX-SLP
#  24                                             MX-SIN
#  25                                             MX-SON
#  26                                             MX-TAB
#  27                                             MX-TAM
#  28                                             MX-TLA
#  29                                             MX-VER
#  30                                             MX-YUC
#  31                                             MX-ZAC
#  32  Notas: ↑ Registro Nacional de Población México...  ,
#                          0                                   1
#  0  Control de autoridades  Proyectos Wikimedia  Datos: Q28197]

# %%
print(type(df_html[0]))
df_html[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                                Estado  \
# 0                                      Aguascalientes
# 1                                     Baja California
# 2                                 Baja California Sur
# 3                                            Campeche
# 4                                             Chiapas
# 5                                           Chihuahua
# 6                                    Ciudad de México
# 7                                            Coahuila
# 8                                              Colima
# 9                                             Durango
# 10                                         Guanajuato
# 11                                           Guerrero
# 12                                            Hidalgo
# 13                                            Jalisco
# 14                                             México
# 15                                          Michoacán
# 16                                            Morelos
# 17                                            Nayarit
# 18                                         Nuevo León
# 19                                             Oaxaca
# 20                                             Puebla
# 21                                          Querétaro
# 22                                       Quintana Roo
# 23                                    San Luis Potosí
# 24                                            Sinaloa
# 25                                             Sonora
# 26                                            Tabasco
# 27                                         Tamaulipas
# 28                                           Tlaxcala
# 29                                           Veracruz
# 30                                            Yucatán
# 31                                          Zacatecas
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                              Variable  \
# 0                                                Ags.
# 1                                                B.C.
# 2                                              B.C.S.
# 3                                               Camp.
# 4                                               Chis.
# 5                                               Chih.
# 6                                             C.D.Mx.
# 7                                               Coah.
# 8                                                Col.
# 9                                                Dgo.
# 10                                               Gto.
# 11                                               Gro.
# 12                                               Hgo.
# 13                                               Jal.
# 14                                      Edo. Méx.[D]​
# 15                                              Mich.
# 16                                               Mor.
# 17                                               Nay.
# 18                                               N.L.
# 19                                               Oax.
# 20                                               Pue.
# 21                                               Qro.
# 22                                        Q. Roo.[F]​
# 23                                             S.L.P.
# 24                                               Sin.
# 25                                               Son.
# 26                                               Tab.
# 27                                             Tamps.
# 28                                              Tlax.
# 29                                               Ver.
# 30                                               Yuc.
# 31                                               Zac.
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                            RENAPO[A]​  \
# 0                                                  AS
# 1                                                  BC
# 2                                                  BS
# 3                                                  CC
# 4                                                  CS
# 5                                                  CH
# 6                                                  DF
# 7                                                  CL
# 8                                                  CM
# 9                                                  DG
# 10                                                 GT
# 11                                                 GR
# 12                                                 HG
# 13                                                 JC
# 14                                                 MC
# 15                                                 MN
# 16                                                 MS
# 17                                                 NT
# 18                                                 NL
# 19                                                 OC
# 20                                                 PL
# 21                                                 QO
# 22                                                 QR
# 23                                                 SP
# 24                                                 SL
# 25                                                 SR
# 26                                                 TC
# 27                                                 TS
# 28                                                 TL
# 29                                                 VZ
# 30                                                 YN
# 31                                                 ZS
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                            Dos letras  \
# 0                                                  AG
# 1                                                  BC
# 2                                                  BS
# 3                                                  CM
# 4                                                  CS
# 5                                                  CH
# 6                                              CX[B]​
# 7                                                  CO
# 8                                                  CL
# 9                                                  DG
# 10                                                 GT
# 11                                                 GR
# 12                                                 HG
# 13                                                 JC
# 14                                             EM[E]​
# 15                                                 MI
# 16                                                 MO
# 17                                                NaN
# 18                                                 NL
# 19                                                 OA
# 20                                                 PU
# 21                                                 QT
# 22                                                 QR
# 23                                                 SL
# 24                                                 SI
# 25                                                 SO
# 26                                                 TB
# 27                                                 TM
# 28                                                 TL
# 29                                                 VE
# 30                                                 YU
# 31                                                 ZA
# 32  Notas: ↑ Registro Nacional de Población México...
#
#                                 Completo (ISO 3166-2)
# 0                                              MX-AGU
# 1                                              MX-BCN
# 2                                              MX-BCS
# 3                                              MX-CAM
# 4                                              MX-CHP
# 5                                              MX-CHH
# 6                                          MX-CMX[C]​
# 7                                              MX-COA
# 8                                              MX-COL
# 9                                              MX-DUR
# 10                                             MX-GUA
# 11                                             MX-GRO
# 12                                             MX-HID
# 13                                             MX-JAL
# 14                                             MX-MEX
# 15                                             MX-MIC
# 16                                             MX-MOR
# 17                                             MX-NAY
# 18                                             MX-NLE
# 19                                             MX-OAX
# 20                                             MX-PUE
# 21                                             MX-QUE
# 22                                             MX-ROO
# 23                                             MX-SLP
# 24                                             MX-SIN
# 25                                             MX-SON
# 26                                             MX-TAB
# 27                                             MX-TAM
# 28                                             MX-TLA
# 29                                             MX-VER
# 30                                             MX-YUC
# 31                                             MX-ZAC
# 32  Notas: ↑ Registro Nacional de Población México...

# %%
print(df_html[0].index)
df_html[0].drop(32, axis=0, inplace=True)
df_html[0]
# Out:
# RangeIndex(start=0, stop=33, step=1)
#                  Estado       Variable RENAPO[A]​ Dos letras  \
# 0        Aguascalientes           Ags.         AS         AG
# 1       Baja California           B.C.         BC         BC
# 2   Baja California Sur         B.C.S.         BS         BS
# 3              Campeche          Camp.         CC         CM
# 4               Chiapas          Chis.         CS         CS
# 5             Chihuahua          Chih.         CH         CH
# 6      Ciudad de México        C.D.Mx.         DF     CX[B]​
# 7              Coahuila          Coah.         CL         CO
# 8                Colima           Col.         CM         CL
# 9               Durango           Dgo.         DG         DG
# 10           Guanajuato           Gto.         GT         GT
# 11             Guerrero           Gro.         GR         GR
# 12              Hidalgo           Hgo.         HG         HG
# 13              Jalisco           Jal.         JC         JC
# 14               México  Edo. Méx.[D]​         MC     EM[E]​
# 15            Michoacán          Mich.         MN         MI
# 16              Morelos           Mor.         MS         MO
# 17              Nayarit           Nay.         NT        NaN
# 18           Nuevo León           N.L.         NL         NL
# 19               Oaxaca           Oax.         OC         OA
# 20               Puebla           Pue.         PL         PU
# 21            Querétaro           Qro.         QO         QT
# 22         Quintana Roo    Q. Roo.[F]​         QR         QR
# 23      San Luis Potosí         S.L.P.         SP         SL
# 24              Sinaloa           Sin.         SL         SI
# 25               Sonora           Son.         SR         SO
# 26              Tabasco           Tab.         TC         TB
# 27           Tamaulipas         Tamps.         TS         TM
# 28             Tlaxcala          Tlax.         TL         TL
# 29             Veracruz           Ver.         VZ         VE
# 30              Yucatán           Yuc.         YN         YU
# 31            Zacatecas           Zac.         ZS         ZA
#
#    Completo (ISO 3166-2)
# 0                 MX-AGU
# 1                 MX-BCN
# 2                 MX-BCS
# 3                 MX-CAM
# 4                 MX-CHP
# 5                 MX-CHH
# 6             MX-CMX[C]​
# 7                 MX-COA
# 8                 MX-COL
# 9                 MX-DUR
# 10                MX-GUA
# 11                MX-GRO
# 12                MX-HID
# 13                MX-JAL
# 14                MX-MEX
# 15                MX-MIC
# 16                MX-MOR
# 17                MX-NAY
# 18                MX-NLE
# 19                MX-OAX
# 20                MX-PUE
# 21                MX-QUE
# 22                MX-ROO
# 23                MX-SLP
# 24                MX-SIN
# 25                MX-SON
# 26                MX-TAB
# 27                MX-TAM
# 28                MX-TLA
# 29                MX-VER
# 30                MX-YUC
# 31                MX-ZAC

# %%
url1 = 'https://en.wikipedia.org/w/index.php?title=Solar_power&oldid=1022764142'
df_html2 = pd.read_html(url1)
print(type(df_html2))
print("Numero de tablas en DF", len(df_html2))
# Out:
# <class 'list'>
# Numero de tablas en DF 22

# %%
df_html2[2]
# Out:
#                                  Name        Country  Capacity MWp  \
# 0                 Pavagada Solar Park          India          2050
# 1           Tengger Desert Solar Park          China          1547
# 2                   Bhadla Solar Park          India          1515
# 3       Kurnool Ultra Mega Solar Park          India          1000
# 4  Datong Solar Power Top Runner Base          China          1000
# 5          Longyangxia Dam Solar Park          China           850
# 6               Rewa Ultra Mega Solar          India           750
# 7         Kamuthi Solar Power Project          India           648
# 8               Solar Star (I and II)  United States           579
# 9                    Topaz Solar Farm  United States           550
#
#    Generation GWh p.a.  Size km2  \
# 0                  NaN        53
# 1                  NaN        43
# 2                  NaN        40
# 3                  NaN        24
# 4                  NaN       NaN
# 5                  NaN        23
# 6                  NaN       NaN
# 7                  NaN      10.1
# 8               1664.0        13
# 9               1301.0  24.6[74]
#
#    .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Year  \
# 0                                               2017
# 1                                               2016
# 2                                               2017
# 3                                               2017
# 4                                               2016
# 5                                               2015
# 6                                               2018
# 7                                               2016
# 8                                               2015
# 9                                               2014
#
#                     Ref
# 0           [2][53][54]
# 1              [55][56]
# 2          [57][58][59]
# 3                  [60]
# 4          [61][62][63]
# 5  [64][65][66][67][68]
# 6                  [69]
# 7              [70][71]
# 8              [72][73]
# 9          [75][76][77]

# %%
i = 0
for dfh in df_html2:
    print(str(i).center(60,"*"))
    dfh.info()
    i = i + 1
# Out:
# *****************************0******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7 non-null      object
# dtypes: object(1)
# memory usage: 184.0+ bytes
# *****************************1******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   (Solar Electricity Generation, Year)          16 non-null     object
#  1   (Solar Electricity Generation, Energy (TWh))  16 non-null     object
#  2   (Solar Electricity Generation, % of Total)    16 non-null     object
# dtypes: object(3)
# memory usage: 512.0+ bytes
# *****************************2******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Name                                                                         10 non-null     object
#  1   Country                                                                      10 non-null     object
#  2   Capacity MWp                                                                 10 non-null     int64
#  3   Generation GWh p.a.                                                          2 non-null      float64
#  4   Size km2                                                                     8 non-null      object
#  5   .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Year  10 non-null     int64
#  6   Ref                                                                          10 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 688.0+ bytes
# *****************************3******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           11 non-null     object
#  1   Capacity (MW)  11 non-null     object
#  2   Location       11 non-null     object
#  3   Notes          11 non-null     object
# dtypes: object(4)
# memory usage: 480.0+ bytes
# *****************************4******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes
# *****************************5******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       0 non-null      float64
#  1   1       1 non-null      object
# dtypes: float64(1), object(1)
# memory usage: 144.0+ bytes
# *****************************6******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
# dtypes: object(1)
# memory usage: 144.0+ bytes
# *****************************7******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vteSolar energy    24 non-null     object
#  1   vteSolar energy.1  24 non-null     object
#  2   vteSolar energy.2  2 non-null      object
# dtypes: object(3)
# memory usage: 704.0+ bytes
# *****************************8******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6 non-null      object
#  1   1       6 non-null      object
# dtypes: object(2)
# memory usage: 224.0+ bytes
# *****************************9******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************10*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       8 non-null      object
#  1   1       8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
# *****************************11*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   vteSolar power by country    8 non-null      object
#  1   vteSolar power by country.1  8 non-null      object
# dtypes: object(2)
# memory usage: 256.0+ bytes
# *****************************12*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vtePhotovoltaics    22 non-null     object
#  1   vtePhotovoltaics.1  22 non-null     object
# dtypes: object(2)
# memory usage: 480.0+ bytes
# *****************************13*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************14*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************15*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5 non-null      object
#  1   1       5 non-null      object
# dtypes: object(2)
# memory usage: 208.0+ bytes
# *****************************16*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
#  1   1       3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
# *****************************17*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# *****************************18*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   vteElectricity delivery    11 non-null     object
#  1   vteElectricity delivery.1  11 non-null     object
#  2   vteElectricity delivery.2  1 non-null      object
# dtypes: object(3)
# memory usage: 392.0+ bytes
# *****************************19*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# *****************************20*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   vteRenewable energy by country and territory    9 non-null      object
#  1   vteRenewable energy by country and territory.1  9 non-null      object
# dtypes: object(2)
# memory usage: 272.0+ bytes
# *****************************21*****************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes

# %%
url2 = 'http://ingenieria.aragon.unam.mx/ico/alumnos/examenes_extraordinarios.rb'
df_html3 = pd.read_html(url2)
print(type(df_html3))
print("Numero de tablas en DF", len(df_html3))

# %% [markdown]
# ## TAREA

# %% [markdown]
# ###  DF con varias tablas de una URL

# %%
url4 = 'https://es.wikipedia.org/wiki/Europa'
df_html4 = pd.read_html(url4)
print(type(df_html4))
print("Numero de tablas en DF:", len(df_html4))
# Out:
# <class 'list'>
# Numero de tablas en DF: 13

# %%
df_html4[1]
# Out:
#     Bandera                              Nombre/Nombre oficial Establecido  \
# 0       NaN                       Albania República de Albania        1912
# 1       NaN             Alemania República Federal de Alemania        1871
# 2       NaN                    Andorra Coprincipado de Andorra        1278
# 3       NaN                       Armenia República de Armenia        1991
# 4       NaN                       Austria República de Austria        1918
# 5       NaN                 Azerbaiyán República de Azerbaiyán        1991
# 6       NaN                           Bélgica Reino de Bélgica        1830
# 7       NaN               Bielorrusia República de Bielorrusia        1991
# 8       NaN                               Bosnia y Herzegovina        1992
# 9       NaN                     Bulgaria República de Bulgaria        1908
# 10      NaN                         Chipre República de Chipre        1960
# 11      NaN                       Croacia República de Croacia        1991
# 12      NaN                       Dinamarca Reino de Dinamarca         935
# 13      NaN                      Eslovaquia República Eslovaca        1993
# 14      NaN                   Eslovenia República de Eslovenia        1991
# 15      NaN                             España Reino de España        1516
# 16      NaN                       Estonia República de Estonia        1991
# 17      NaN                   Finlandia República de Finlandia        1918
# 18      NaN                         Francia República Francesa         843
# 19      NaN                          Georgia Estado de Georgia        1991
# 20      NaN                          Grecia República Helénica        1832
# 21      NaN                                            Hungría        1918
# 22      NaN                       Irlanda República de Irlanda        1937
# 23      NaN                     Islandia República de Islandia        1944
# 24      NaN                          Italia República Italiana        1861
# 25      NaN                       Letonia República de Letonia        1991
# 26      NaN          Liechtenstein Principado de Liechtenstein        1719
# 27      NaN                     Lituania República de Lituania        1991
# 28      NaN               Luxemburgo Gran Ducado de Luxemburgo        1890
# 29      NaN  Macedonia del Norte República de Macedonia del...        1991
# 30      NaN                           Malta República de Malta        1974
# 31      NaN                     Moldavia República de Moldavia        1991
# 32      NaN                        Mónaco Principado de Mónaco        1861
# 33      NaN                                         Montenegro        2006
# 34      NaN                           Noruega Reino de Noruega        1905
# 35      NaN             Países Bajos Reino de los Países Bajos        1815
# 36      NaN                       Polonia República de Polonia        1918
# 37      NaN                      Portugal República Portuguesa        1139
# 38      NaN  Reino Unido Reino Unido de Gran Bretaña e Irla...        1801
# 39      NaN                                    República Checa        1993
# 40      NaN                                            Rumania        1878
# 41      NaN                              Rusia Federación Rusa        1547
# 42      NaN      San Marino Serenísima República de San Marino        1243
# 43      NaN                         Serbia República de Serbia        1878
# 44      NaN                             Suecia Reino de Suecia        1523
# 45      NaN                          Suiza Confederación Suiza        1815
# 46      NaN                       Turquía República de Turquía        1923
# 47      NaN                                            Ucrania        1991
# 48      NaN                                      Unión Europea        1993
# 49      NaN          Vaticano Estado de la Ciudad del Vaticano        1929
# 50      NaN                                                NaN       Total
#
#    Superficie (km²)    Población Habitantes  por km²               Capital  \
# 0            28 748    3 038 594                1056                Tirana
# 1           357 022   80 722 792                2261                Berlín
# 2               468       85 660                 183      Andorra la Vieja
# 3            29 749    3 229 900                1085                Ereván
# 4            83 871    8 711 770                1038                 Viena
# 5            86 600    9 872 765                 114                  Bakú
# 6            30 528   11 409 077                3737              Bruselas
# 7           207 600    9 570 376                 461                 Minsk
# 8            51 917    3 861 912                 754              Sarajevo
# 9           110 879    7 144 653                 644                 Sofía
# 10             9251    1 205 575                1303               Nicosia
# 11           56 594    4 313 707                 762                Zagreb
# 12           43 094    5 593 785                1298            Copenhague
# 13           49 035    5 445 802                 111            Bratislava
# 14           20 273    1 978 029                 975             Liubliana
# 15          505 370   47 435 597                  94                Madrid
# 16           45 228    1 258 545                 278                Tallin
# 17          338 415    5 948 211                 162              Helsinki
# 18          643 801   66 836 154                1038                 París
# 19           69 700    4 928 052                 707                Tiflis
# 20          131 957   10 773 253                 816                Atenas
# 21           93 028    9 874 784                1061              Budapest
# 22           70 273    4 952 473                 704                Dublín
# 23          103 000      335 878                  32             Reikiavik
# 24          301 340   62 007 540                2057                  Roma
# 25           64 589    1 965 686                 304                  Riga
# 26              160       37 937                2371                 Vaduz
# 27           65 300    2 854 235                 437                 Vilna
# 28             2586      582 291                2251  Ciudad de Luxemburgo
# 29           25 713    2 100 025                 816                Skopie
# 30              316      415 196               13139             La Valeta
# 31           33 851    3 510 485                1037              Chisináu
# 32                2       30 581            15 290,5      Ciudad de Mónaco
# 33           13 812      644 578                 466             Podgorica
# 34          323 802    5 265 158                 162                  Oslo
# 35      41 543[18]​   17 016 967                4096             Ámsterdam
# 36          312 685   38 652 326                1232              Varsovia
# 37      92 090[19]​   10 833 816                1176                Lisboa
# 38          243 610   64 430 428                2644               Londres
# 39           78 867   10 644 842                1349                 Praga
# 40          238 391   21 599 736                 906              Bucarest
# 41       17 098 242  142 355 415                  83                 Moscú
# 42               61       33 285                5456  Ciudad de San Marino
# 43           77 474    7 143 921                9292              Belgrado
# 44          450 295    9 880 604                 219             Estocolmo
# 45           41 277    8 179 294                1981                 Berna
# 46          783 562   84 614 362                 110                Ankara
# 47          603 550   44 209 733                 732                  Kiev
# 48        4 324 782  513 949 445                1188              Bruselas
# 49              044         1000               22727   Ciudad del Vaticano
# 50       10 530 751  743 704 000                 700                   NaN
#
#    Idioma(s) oficial(es)
# 0                     sq
# 1                     de
# 2                     ca
# 3                     hy
# 4                     de
# 5                     az
# 6               nl/fr/de
# 7                  ru/be
# 8               bs/hr/sr
# 9                     bg
# 10                 el/tk
# 11                    hr
# 12              da/fo/kl
# 13                    sk
# 14                    sl
# 15           es/ca/gl/eu
# 16                    et
# 17                 fi/sv
# 18                    fr
# 19                    ka
# 20                    el
# 21                    hu
# 22                 ga/en
# 23                    is
# 24                    it
# 25                    lv
# 26                    de
# 27                    lt
# 28              lb/fr/de
# 29                 mk/sq
# 30                 mt/en
# 31                    ro
# 32                    fr
# 33                   n/d
# 34                    no
# 35                    nl
# 36                    pl
# 37                    pt
# 38           en/cy/gd/ga
# 39                    cs
# 40                    ro
# 41                    ru
# 42                    it
# 43                    sr
# 44                    sv
# 45           de/fr/it/rm
# 46                    tr
# 47                    uk
# 48                    24
# 49                 la/it
# 50                   NaN

# %%
df_html4[2]
# Out:
#    Bandera                          Nombre/ Nombre oficial Declaración  \
# 0      NaN                    Abjasia República de Abjasia        2008
# 1      NaN                      Kosovo República de Kosovo        2008
# 2      NaN                             República de Artsaj        1991
# 3      NaN             República Turca del Norte de Chipre        1983
# 4      NaN      Osetia del Sur República de Osetia del Sur        2008
# 5      NaN  Transnistria República Moldava Pridnestroviana        1990
# 6      NaN                                             NaN       Total
#
#   Superficie (km²)  Población  Densidad de población (por km²)      Capital  \
# 0             8432    216 000                             2824       Sujumi
# 1           10 887  1 883 018                             1729     Pristina
# 2           11 458    138 800                             1211  Stepanakert
# 3             3355    265 100                               86      Nicosia
# 4             3900     70 000                               21     Tsjinval
# 5             4163    537 000                              133     Tiráspol
# 6           42 195  3 031 738                              718          NaN
#
#   Idioma(s) oficial(es)
# 0                 ab/ru
# 1                 sq/sr
# 2                    hy
# 3                    tk
# 4              os/ru/ka
# 5              ru/ro/uk
# 6                   NaN

# %%
df_html4[3]
# Out:
#    Bandera                       Nombre/ Nombre oficial  Estatus       Estado  \
# 0      NaN   Acrotiri y Dhekelia Territorio de ultramar   1960.0  Reino Unido
# 1      NaN             Gibraltar Territorio de ultramar   2002.0  Reino Unido
# 2      NaN  Bailía de Guernsey Dependencia de la Corona   1204.0  Reino Unido
# 3      NaN    Bailía de Jersey Dependencia de la Corona   1204.0  Reino Unido
# 4      NaN         Isla de Man Dependencia de la Corona   1765.0  Reino Unido
# 5      NaN              Svalbard Territorio de ultramar   2002.0      Noruega
# 6      NaN                                          NaN      NaN        Total
#
#   Superficie (km²) Población  Habitantes por km²           Capital  \
# 0              123    15 700                1276          Episkopi
# 1               59    29 328               41897         Gibraltar
# 2               78    66 297                8499  Saint Peter Port
# 3              116    98 069                8454      Saint Helier
# 4              572    88 195                1541           Douglas
# 5           62 045      1872                   3      Longyearbyen
# 6         62 939,9   299 461                   5               NaN
#
#   Idioma(s) oficial(es)
# 0                    en
# 1                    en
# 2                 en/fr
# 3                 en/fr
# 4                 en/gv
# 5                    no
# 6                   NaN

# %%
df_html4[5]
# Out:
#     Países                    Moneda
# 0      NaN             Euro (€, EUR)
# 1      NaN  Libra esterlina (£, GBP)
# 2      NaN        Franco suizo (CHF)
# 3      NaN          Rublo ruso (RUB)
# 4      NaN             Corona danesa
# 5      NaN                       Lek
# 6      NaN    Rublo bielorruso (BYR)
# 7      NaN   Marco convertible (BHK)
# 8      NaN                 Lev (BGN)
# 9      NaN            Florín húngaro
# 10     NaN    Corona islandesa (ISK)
# 11     NaN               Tenge (KZT)
# 12     NaN     Dinar macedonio (MKD)
# 13     NaN         Leu moldavo (MDL)
# 14     NaN          Corona (kr, NOK)
# 15     NaN              Esloti (PLN)
# 16     NaN        Corona checa (CZK)
# 17     NaN                 Leu (RON)
# 18     NaN               Dinar (RSD)
# 19     NaN          Corona (kr, SEK)
# 20     NaN              Grivna (UAH)

# %% [markdown]
# ### DF alumnos "bdcolegio02"

# %%
from sqlalchemy import create_engine

us = 'fesalu'
passwd = 'bdfes2023'
url = 'bd.arcelia.net'
puerto = '3306'
bd = 'bdcolegio02'
auth = 'mysql_native_password'

str_conn = 'mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}?auth_plugin={5}'
str_conn = str_conn.format(us, passwd, url, puerto, bd, auth)
str_conn
# Out:
# 'mysql+mysqlconnector://fesalu:bdfes2023@bd.arcelia.net:3306/bdcolegio02?auth_plugin=mysql_native_password'

# %%
conn = create_engine(str_conn)
conn
# Out:
# Engine(mysql+mysqlconnector://fesalu:***@bd.arcelia.net:3306/bdcolegio02?auth_plugin=mysql_native_password)

# %%
sql = '''SELECT * FROM alumnos WHERE sexo = 'M' '''
df_mysql = pd.read_sql_query(sql=sql, con=conn)
print(type(df_mysql))
df_mysql
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     clave_alu clave_admin  ap_paterno ap_materno          nombre sexo  \
# 0    11030177        4716    FERRUSCA    ANDRADE         OCTAVIO    M
# 1    11030178        4720      GARCIA      GOMEZ          RAFAEL    M
# 2    11030180        5380   GUTIERREZ     FLORES    CARLOS DAVID    M
# 3    11030188        4857    MARTINEZ     RIVERA    JAVIER JOSUE    M
# 4    11030199        4769     ROSALES     APREZA   NESTOR MARTIN    M
# ..        ...         ...         ...        ...             ...  ...
# 394  11080203              VILLAGRANA   BARRAGAN     CARLOS IVAN    M
# 395  11080204                AGUILLON   RESENDIZ            JOSE    M
# 396  11080206                    NAVA     TORRES  LEONARDO JESUS    M
# 397  11080207                   LOPEZ    AGUILAR          DANIEL    M
# 398  11080210                GUERRERO  COLOMBRES     ALDO ENRICO    M
#
#                    curp  peso  estatura                         direccion  \
# 0                        62.0      1.68           MARQUES DE BARCELO #608
# 1       220140190055288  55.0      1.82                     PAJAROS # 687
# 2    GUFC910124HDFTLR04  60.0      1.75    CIRCUITO SAN IGNACIO 670 INT 6
# 3    MARJ910422HQTRVV01  52.0      1.66                  ASUNCION NO. 698
# 4                        53.0      1.63                   RIO BALSAS #707
# ..                  ...   ...       ...                               ...
# 394  VIBC911114HDFLRR06  61.0      1.72  MARQUES DE LAS AMARILLAS NO. 687
# 395  AURJ941216HQTGSS06  57.0    160.00             EULOGIO MARROQUIN 707
# 396    NATL9408HDFVRN05   0.0      0.00               PASEO DE MOSCU #868
# 397  LOAD940404HBCPGN06   0.0      0.00          HDA DE LOS MORALES # 707
# 398  GUCA960125HDFRLL09  44.0      1.59                        AVENIDA PE
#
#                       colonia     cp                 ciudad  id_estado  \
# 0           LOMAS DEL MARUQES  26146              QUERETARO         22
# 1      CALESA SEGUNDA SECCION  26020              QUERETARO         22
# 2    FRACCIONAMIENTO SANTIAGO  26129              QUERETARO         22
# 3                  EL ROSARIO  26128               QUERETRO         22
# 4                LOS ARQUITOS  26050              QUERETARO         22
# ..                        ...    ...                    ...        ...
# 394         LOMAS DEL MARQUES  26146              QUERETARO         22
# 395                  CANDILES  26190              QUERETARO         22
# 396                    TEJEDA  26190              QUERETARO         22
# 397       RINCON DE LOS ARCOS  36636                IRPUATO         12
# 398            SAN PEDRITO PE         SANTIAGO DE QUERETARO         22
#
#                 delegacion       telefono        celular  \
# 0                QUERETARO     4458114845     9618114845
# 1                QUERETARO     4451986967     9611986967
# 2    SANTIAGO DE QUERETARO     4455558865     9612558865
# 3                QUERETARO  0444458817907  0449618817907
# 4            QUERETARO SUR  0444458591085  0449618291082
# ..                     ...            ...            ...
# 394  SANTIAGO DE QUERETARO     4458517765     9618517765
# 395            CORREGIDORA     4458170450     9618170420
# 396  SANTIAGO DE QUERETARO     4458770708     9618770708
# 397               IRAPUATO     4651551906     4621251906
# 398                            5585511084     5582211084
#
#                                      email status_alu              fedita
# 0                tavoferrus_11@miemail.com         AC 2021-10-15 16:23:00
# 1            arobertogarcia@telmart.net.mx         AC 2021-10-25 09:22:33
# 2                 chorok_skp91@miemail.com         AC 2021-09-27 21:52:05
# 3    c_h_a_p_a_r_r_o-pi_cha_ka@miemail.com         AC 2022-10-11 20:23:14
# 4                     nestoriwh@hotmai.com         AC 2021-09-22 17:57:13
# ..                                     ...        ...                 ...
# 394              chino-vergoza@miemail.com         AS 2023-03-08 16:53:59
# 395          blackjarrior_9412@miemail.com         AS 2023-03-10 11:05:13
# 396              leo94-88@infinitum.com.mx         AS 2023-03-11 19:56:28
# 397                   marydm72@miemail.com         AS 2023-03-07 11:17:06
# 398                  colombresm@att.com.mx         AS 2023-04-15 20:48:37
#
# [399 rows x 20 columns]
